# %%
from string import ascii_letters
import numpy as np
import pandas as pd
#import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
guns_2020 = pd.read_csv("../data/guns_2020.csv")
guns_2020.shape
# Out:
# (45222, 10)

# %%
guns_2020 = pd.read_csv("../data/guns_2020.csv")
guns_2020.head(20)
# Out:
#     year  month    intent  police sex   age                            race  \
# 0   2020      1   Suicide       0   M  64.0                           White
# 1   2020      1   Suicide       0   F  39.0                           White
# 2   2020      1   Suicide       0   M  20.0  Native American/Native Alaskan
# 3   2020      1   Suicide       0   F  65.0                           White
# 4   2020      1   Suicide       0   M  31.0                        Hispanic
# 5   2020      1   Suicide       0   M  30.0                           White
# 6   2020      1  Homicide       1   M  59.0                           White
# 7   2020      1   Suicide       0   M  24.0  Native American/Native Alaskan
# 8   2020      1   Suicide       0   M  80.0                           White
# 9   2020      1   Suicide       0   M  77.0                           White
# 10  2020      1   Suicide       0   M  19.0  Native American/Native Alaskan
# ...
